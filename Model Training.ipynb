# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt

# %%
# Constants
BATCH_SIZE = 32
IMG_SIZE = 256
CHANNELS = 3
EPOCHS = 50
NUM_CLASSES = 4

# %%
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    "/content/drive/MyDrive/Wheat_Dataset/Training/Wheat_Disease",
    shuffle=True,
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
)
# Out:
# Found 3756 files belonging to 4 classes.

# %%
class_names = dataset.class_names
print("Classes:", class_names)
# Out:
# Classes: ['Black Rust', 'Brown Rust', 'Healthy Wheat', 'Yellow Rust']

# %%
for images_batch,label_batch in dataset.take(1):
    print(images_batch.shape)
    print(label_batch.numpy())
# Out:
# (32, 256, 256, 3)
# [1 2 1 3 1 1 1 3 3 2 1 3 2 2 1 1 1 3 1 2 0 1 1 2 3 3 1 1 3 0 1 0]

# %%
for images_batch, label_batch in dataset.take(1):
    print(images_batch.shape)
    print(label_batch.numpy())

    plt.figure(figsize=(12, 9))
    for i in range(min(12, images_batch.shape[0])):
        ax = plt.subplot(3, 4, i + 1)
        plt.imshow(images_batch[i].numpy().astype("uint8"))
        plt.title(dataset.class_names[label_batch[i]])
        plt.axis("off")
    plt.tight_layout()
    plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# 80% ==> Training
# 20% ==> test
#   10% ==> Validation
#   10% ==> Test

# %%
train_size = 0.8
len(dataset)
# Out:
# 118

# %%
118*32
# Out:
# 3776

# %%
train_size = 0.8
len(dataset) * train_size
# Out:
# 94.4

# %%
train_ds = dataset.take(94)
len(train_ds)
# Out:
# 94

# %%
test_ds = dataset.skip(94)
len(test_ds)
# Out:
# 24

# %%
val_size = 0.1
len(dataset) * val_size
# Out:
# 11.8

# %%
val_ds = test_ds.take(11)
len(val_ds)
# Out:
# 11

# %%
test_ds = test_ds.skip(11)
len(test_ds)
# Out:
# 13

# %%
import tensorflow as tf

def get_dataset_partitions_tf(ds, train_split=0.8, val_split=0.1, test_split=0.1,
                               shuffle=True, shuffle_size=10000):
    # Total number of samples in the dataset
    ds_size = len(ds)
    if shuffle:
        ds = ds.shuffle(shuffle_size, seed=42)

    train_size = int(train_split * ds_size)
    val_size = int(val_split * ds_size)

    train_ds = ds.take(train_size)
    val_ds = ds.skip(train_size).take(val_size)
    test_ds = ds.skip(train_size + val_size)

    return train_ds, val_ds, test_ds

# %%
train_ds, val_ds, test_ds = get_dataset_partitions_tf(dataset)

# %%
len(train_ds)
# Out:
# 94

# %%
len(val_ds)
# Out:
# 11

# %%
len(test_ds)
# Out:
# 13

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
test_ds = test_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)

# %%
for image_batch , label_batch in dataset.take(1):
    print(image_batch[0].numpy()/255)
# Out:
# [[[0.38431373 0.56078434 0.23529412]
#   [0.3529412  0.5019608  0.20784314]
#   [0.44705883 0.54509807 0.31764707]
#   ...
#   [0.27450982 0.38039216 0.3137255 ]
#   [0.23137255 0.34509805 0.27450982]
#   [0.20392157 0.3254902  0.25490198]]
#
#  [[0.41960785 0.5921569  0.24313726]
#   [0.42745098 0.5803922  0.2627451 ]
#   [0.32941177 0.4509804  0.1882353 ]
#   ...
#   [0.2784314  0.38431373 0.31764707]
#   [0.23921569 0.3529412  0.28235295]
#   [0.2        0.32156864 0.2509804 ]]
#
#  [[0.4627451  0.63529414 0.2509804 ]
#   [0.42352942 0.5921569  0.23137255]
#   [0.43529412 0.5882353  0.27058825]
#   ...
#   [0.27058825 0.3764706  0.3019608 ]
#   [0.23921569 0.3529412  0.28235295]
#   [0.2        0.3137255  0.24313726]]
#
#  ...
#
#  [[0.10196079 0.20392157 0.05098039]
#   [0.17254902 0.27450982 0.12941177]
#   [0.08627451 0.1882353  0.05098039]
#   ...
#   [0.8156863  0.8117647  0.6       ]
#   [0.7764706  0.77254903 0.54901963]
#   [0.93333334 0.93333334 0.69803923]]
#
#  [[0.10980392 0.21960784 0.07058824]
#   [0.20784314 0.31764707 0.16862746]
#   [0.13333334 0.23921569 0.10196079]
#   ...
#   [0.7921569  0.80784315 0.5764706 ]
#   [0.93333334 0.9490196  0.7176471 ]
#   [0.68235296 0.7058824  0.47058824]]
#
#  [[0.41568628 0.53333336 0.38431373]
#   [0.4        0.5176471  0.36862746]
#   [0.24705882 0.3529412  0.22352941]
#   ...
#   [0.8745098  0.8980392  0.654902  ]
#   [0.81960785 0.8509804  0.61960787]
#   [0.60784316 0.6392157  0.40784314]]]

# %%
resize_and_rescale = tf.keras.Sequential([
    layers.Resizing(IMG_SIZE, IMG_SIZE),
    layers.Rescaling(1.0/255)
])

# %%
data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal_and_vertical"),
    layers.RandomRotation(0.1),
])

# %%
model = models.Sequential([
    layers.Input(shape=(IMG_SIZE, IMG_SIZE, CHANNELS)),  # ✅ Correct way to set input shape

    resize_and_rescale,
    data_augmentation,

    layers.Conv2D(32, kernel_size=(3,3), activation="relu"),
    layers.MaxPooling2D((2,2)),

    layers.Conv2D(64, kernel_size=(3,3), activation="relu"),
    layers.MaxPooling2D((2,2)),

    layers.Conv2D(64, kernel_size=(3,3), activation="relu"),
    layers.MaxPooling2D((2,2)),

    layers.Conv2D(64, kernel_size=(3,3), activation="relu"),
    layers.MaxPooling2D((2,2)),

    layers.Conv2D(64, kernel_size=(3,3), activation="relu"),
    layers.MaxPooling2D((2,2)),

    layers.Conv2D(64, kernel_size=(3,3), activation="relu"),
    layers.MaxPooling2D((2,2)),

    layers.Flatten(),
    layers.Dense(64, activation="relu"),
    layers.Dense(NUM_CLASSES, activation="softmax")
])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ sequential (Sequential)         │ (None, 256, 256, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_1 (Sequential)       │ (None, 256, 256, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 254, 254, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 127, 127, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 125, 125, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 62, 62, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 60, 60, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 30, 30, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 28, 28, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 14, 14, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 12, 12, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 6, 6, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 4, 4, 64)       │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 2, 2, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │        16,448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │           260 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 183,812 (718.02 KB)
#  Trainable params: 183,812 (718.02 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(
    optimizer="adam",
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics=["accuracy"]
)

# %%
 history = model.fit(
    train_ds,
    batch_size = BATCH_SIZE,
    validation_data = val_ds,
    verbose = 1,
    epochs = EPOCHS
)
# Out:
# Epoch 1/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1016s 5s/step - accuracy: 0.3323 - loss: 1.3512 - val_accuracy: 0.3864 - val_loss: 1.3084
# Epoch 2/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 468s 5s/step - accuracy: 0.4115 - loss: 1.2362 - val_accuracy: 0.4602 - val_loss: 1.2751
# Epoch 3/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 435s 5s/step - accuracy: 0.4649 - loss: 1.1341 - val_accuracy: 0.5170 - val_loss: 1.0575
# Epoch 4/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 439s 5s/step - accuracy: 0.4973 - loss: 1.0719 - val_accuracy: 0.5511 - val_loss: 1.0370
# Epoch 5/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 438s 5s/step - accuracy: 0.5338 - loss: 1.0394 - val_accuracy: 0.5682 - val_loss: 1.0728
# Epoch 6/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 432s 5s/step - accuracy: 0.5812 - loss: 1.0299 - val_accuracy: 0.6080 - val_loss: 0.9490
# Epoch 7/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 435s 5s/step - accuracy: 0.6042 - loss: 0.9466 - val_accuracy: 0.6449 - val_loss: 0.8938
# Epoch 8/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 445s 5s/step - accuracy: 0.6425 - loss: 0.9048 - val_accuracy: 0.6619 - val_loss: 0.9359
# Epoch 9/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 431s 5s/step - accuracy: 0.6089 - loss: 0.9790 - val_accuracy: 0.6761 - val_loss: 0.8590
# Epoch 10/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 444s 5s/step - accuracy: 0.6765 - loss: 0.8247 - val_accuracy: 0.6591 - val_loss: 0.7687
# Epoch 11/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 442s 5s/step - accuracy: 0.6585 - loss: 0.8436 - val_accuracy: 0.6903 - val_loss: 0.8243
# Epoch 12/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 440s 5s/step - accuracy: 0.6766 - loss: 0.8142 - val_accuracy: 0.6790 - val_loss: 0.8372
# Epoch 13/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 436s 5s/step - accuracy: 0.7054 - loss: 0.7631 - val_accuracy: 0.7273 - val_loss: 0.7333
# Epoch 14/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 432s 5s/step - accuracy: 0.7144 - loss: 0.7493 - val_accuracy: 0.7244 - val_loss: 0.7163
# Epoch 15/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 448s 5s/step - accuracy: 0.7088 - loss: 0.7117 - val_accuracy: 0.7216 - val_loss: 0.7534
# Epoch 16/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 437s 5s/step - accuracy: 0.7285 - loss: 0.7030 - val_accuracy: 0.7386 - val_loss: 0.6539
# Epoch 17/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 432s 5s/step - accuracy: 0.7129 - loss: 0.7280 - val_accuracy: 0.7159 - val_loss: 0.7177
# Epoch 18/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 444s 5s/step - accuracy: 0.7281 - loss: 0.7093 - val_accuracy: 0.7642 - val_loss: 0.6163
# Epoch 19/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 443s 5s/step - accuracy: 0.7305 - loss: 0.6813 - val_accuracy: 0.7216 - val_loss: 0.7023
# Epoch 20/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 436s 5s/step - accuracy: 0.7434 - loss: 0.6541 - val_accuracy: 0.7614 - val_loss: 0.6791
# Epoch 21/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 437s 5s/step - accuracy: 0.7649 - loss: 0.6285 - val_accuracy: 0.7500 - val_loss: 0.6628
# Epoch 22/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 443s 5s/step - accuracy: 0.7588 - loss: 0.6075 - val_accuracy: 0.7812 - val_loss: 0.5744
# Epoch 23/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 440s 5s/step - accuracy: 0.7533 - loss: 0.6429 - val_accuracy: 0.7642 - val_loss: 0.6099
# Epoch 24/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 435s 5s/step - accuracy: 0.7687 - loss: 0.5953 - val_accuracy: 0.7528 - val_loss: 0.6783
# Epoch 25/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 434s 5s/step - accuracy: 0.7799 - loss: 0.5918 - val_accuracy: 0.7699 - val_loss: 0.5887
# Epoch 26/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 444s 5s/step - accuracy: 0.7722 - loss: 0.5878 - val_accuracy: 0.7841 - val_loss: 0.5782
# Epoch 27/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 437s 5s/step - accuracy: 0.7837 - loss: 0.5402 - val_accuracy: 0.7841 - val_loss: 0.5579
# Epoch 28/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 440s 5s/step - accuracy: 0.7771 - loss: 0.5582 - val_accuracy: 0.7472 - val_loss: 0.6489
# Epoch 29/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 433s 5s/step - accuracy: 0.7869 - loss: 0.5704 - val_accuracy: 0.8068 - val_loss: 0.4959
# Epoch 30/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 435s 5s/step - accuracy: 0.7948 - loss: 0.5302 - val_accuracy: 0.7386 - val_loss: 0.7335
# Epoch 31/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 442s 5s/step - accuracy: 0.8000 - loss: 0.5267 - val_accuracy: 0.6960 - val_loss: 0.7213
# Epoch 32/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 440s 5s/step - accuracy: 0.8048 - loss: 0.5253 - val_accuracy: 0.7869 - val_loss: 0.5175
# Epoch 33/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 440s 5s/step - accuracy: 0.7800 - loss: 0.5465 - val_accuracy: 0.7500 - val_loss: 0.6476
# Epoch 34/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 435s 5s/step - accuracy: 0.7905 - loss: 0.5289 - val_accuracy: 0.7869 - val_loss: 0.5046
# Epoch 35/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 431s 5s/step - accuracy: 0.8052 - loss: 0.4807 - val_accuracy: 0.7415 - val_loss: 0.5939
# Epoch 36/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 453s 5s/step - accuracy: 0.8202 - loss: 0.4538 - val_accuracy: 0.8182 - val_loss: 0.4819
# Epoch 37/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 461s 5s/step - accuracy: 0.8217 - loss: 0.4490 - val_accuracy: 0.8097 - val_loss: 0.4554
# Epoch 38/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 450s 5s/step - accuracy: 0.8154 - loss: 0.4793 - val_accuracy: 0.8011 - val_loss: 0.4813
# Epoch 39/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 456s 5s/step - accuracy: 0.8226 - loss: 0.4466 - val_accuracy: 0.8295 - val_loss: 0.4489
# Epoch 40/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 452s 5s/step - accuracy: 0.8299 - loss: 0.4475 - val_accuracy: 0.8523 - val_loss: 0.4157
# Epoch 41/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 447s 5s/step - accuracy: 0.8378 - loss: 0.4302 - val_accuracy: 0.7898 - val_loss: 0.5184
# Epoch 42/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 456s 5s/step - accuracy: 0.8307 - loss: 0.4365 - val_accuracy: 0.7841 - val_loss: 0.5479
# Epoch 43/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 459s 5s/step - accuracy: 0.8343 - loss: 0.4409 - val_accuracy: 0.8352 - val_loss: 0.4747
# Epoch 44/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 496s 5s/step - accuracy: 0.8273 - loss: 0.4158 - val_accuracy: 0.8267 - val_loss: 0.4581
# Epoch 45/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 452s 5s/step - accuracy: 0.8382 - loss: 0.4200 - val_accuracy: 0.8182 - val_loss: 0.4719
# Epoch 46/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 461s 5s/step - accuracy: 0.8258 - loss: 0.4185 - val_accuracy: 0.8295 - val_loss: 0.4289
# Epoch 47/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 459s 5s/step - accuracy: 0.8461 - loss: 0.4207 - val_accuracy: 0.8295 - val_loss: 0.4387
# Epoch 48/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 495s 5s/step - accuracy: 0.8650 - loss: 0.3414 - val_accuracy: 0.8239 - val_loss: 0.5053
# Epoch 49/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 448s 5s/step - accuracy: 0.8397 - loss: 0.4126 - val_accuracy: 0.8722 - val_loss: 0.3467
# Epoch 50/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 453s 5s/step - accuracy: 0.8652 - loss: 0.3617 - val_accuracy: 0.8352 - val_loss: 0.4117
